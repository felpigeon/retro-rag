# %% [markdown]
# # Generation d'un ensemble de donnes d'evaluation pour l'information retrieval (multichunk)
#
# - On donne 2 chunks (articles) qui parlent du meme jeu a Gemini pour qu'il construise des questions qui doivent etre repondus avec les 2 chunks

# %%
import pandas as pd

from google import genai
from google.genai import types
from google.genai.types import GenerateContentConfig

# %%
import sys
sys.path.append('../../src')

from entity import extract_entities, match_entity
from embeddings import generate_embeddings

# %%
client = genai.Client(api_key='AIzaSyBHqAozRSA30mY_q0TRnWfH9_Dsji-nh2Y')
model_id = "gemini-2.5-flash-preview-04-17"

# %%
system_prompt = """You are helping me creating retrieval dataset. Extract a question from the 2 articles bellow about the game {game}.
The question should be answerable with the 2 articles, but not by only one of them.
Make sure the question contains the name of the game ({game}).
Do not mention the articles in your answer.
Your answer should only be the question, without any additional text."""

# %%
df = pd.read_parquet("../../data/articles.parquet")

# %%
games = df.explode("Game").Game.value_counts()[:100].index.tolist()

# %%
def generate_question_about_game(df, game):
    subset = df[df.Game.apply(lambda x: game in x)].sample(2)

    docs = f"Articles 1:\n{subset.iloc[0].article}\n\nArticles 2:\n{subset.iloc[1].article}"

    response = client.models.generate_content(
        model=model_id,
        contents=docs,
        config=GenerateContentConfig(
            system_instruction=system_prompt.format(game=game),
            thinking_config=types.ThinkingConfig(thinking_budget=0)
        )
    )

    return subset.uuid.tolist(), response.candidates[0].content.parts[0].text

# %%
questions = []

# %%
for game in games[:100]:
    try:
        uuids, question = generate_question_about_game(df, game)
        questions.append((uuids, question))
    except Exception as e:
        print(f"Error generating question for article: {e}")
        continue

# %%
questions_df = pd.DataFrame(questions, columns=['target' , 'question'])

# %%
questions_df
# Out:
#                                                target  \
# 0   [ec5be87e-5d79-46e5-a62f-5814664a798e, ad9be1e...
# 1   [0a5dc19e-1638-4196-bb90-e85a1759bcd6, bb5c7eb...
# 2   [36ea002c-6032-491b-8972-5231df3c721e, 97ce9cd...
# 3   [cf4f870a-3a7a-4370-9266-350171379ba4, cfb95b5...
# 4   [e6f31236-2425-479b-bbc0-91a0bd4a81f6, b5d69db...
# ..                                                ...
# 95  [470ab588-a660-4979-96e2-3718ebf1e1ae, 003d8bf...
# 96  [b6317f0d-c286-4e8e-8678-9ad59083af06, 3bbaef5...
# 97  [a042ef3b-9031-485c-849f-c7a68aa57d70, 6c1e234...
# 98  [87d0203d-cbd6-411e-9c06-72895213815b, 662a530...
# 99  [f1334f62-631c-44d7-a6ca-5b4af72546aa, b0852b4...
#
#                                              question
# 0   Which Sonic the Hedgehog game was released aft...
# 1   What entity was co-owned by Nintendo and named...
# 2   What video games are mentioned alongside Final...
# 3   What year did The Legend of Zelda game influen...
# 4   Which game featuring Popeye that was released ...
# ..                                                ...
# 95  Which Mario franchise game is a compilation of...
# 96  Was God of War III originally released on the ...
# 97  Which video games, besides Asteroids, used the...
# 98  What are some specific connections between Bub...
# 99  When did Phantasy Star Online 2: New Genesis r...
#
# [100 rows x 2 columns]

# %%
entities = questions_df.question.apply(extract_entities)
# Out:
# 2025-05-11T16:02:03.989 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 774ms. StopReason: STOP. Tokens(in/out): 103/55
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      Which Sonic the Hedgehog game was released after Sonic Forces and utilized elements influenced by feedback from it?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Sonic the Hedgehog",
#         "type": "Game"
#       },
#       {
#         "name": "Sonic Forces",
#         "type": "Game"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Sonic the Hedgehog",
#         "type": "Game"
#       },
#       {
#         "name": "Sonic Forces",
#         "type": "Game"
#       }
#     ]
# 2025-05-11T16:02:04.575 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 584ms. StopReason: STOP. Tokens(in/out): 100/52
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      What entity was co-owned by Nintendo and named after their mascot, Mario?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Nintendo",
#         "type": "Publisher"
#       },
#       {
#         "name": "Mario",
#         "type": "Game"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Nintendo",
#         "type": "Publisher"
#       },
#       {
#         "name": "Mario",
#         "type": "Game"
#       }
#     ]
# 2025-05-11T16:02:05.222 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 646ms. StopReason: STOP. Tokens(in/out): 103/31
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      What video games are mentioned alongside Final Fantasy as having similarities in concepts, terminology, or genre?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Final Fantasy",
#         "type": "Game"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Final Fantasy",
#         "type": "Game"
#       }
#     ]
# 2025-05-11T16:02:05.877 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 654ms. StopReason: STOP. Tokens(in/out): 104/56
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      What year did The Legend of Zelda game influence ReCore, and what console was it released on?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "The Legend of Zelda",
#         "type": "Game"
#       },
#       {
#         "name": "ReCore",
#         "type": "Game"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "The Legend of Zelda",
#         "type": "Game"
#       },
#       {
#         "name": "ReCore",
#         "type": "Game"
#       }
#     ]
# 2025-05-11T16:02:06.699 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 821ms. StopReason: STOP. Tokens(in/out): 112/100
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      Which game featuring Popeye that was released on the Famicom does not have a jump button unlike Nintendo's earlier Donkey Kong games?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Popeye",
#         "type": "Game"
#       },
#       {
#         "name": "Famicom",
#         "type": "Console"
#       },
#       {
#         "name": "Donkey Kong",
#         "type": "Game"
#       },
#       {
#         "name": "Nintendo",
#         "type": "Publisher"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Popeye",
#         "type": "Game"
#       },
#       {
#         "name": "Famicom",
#         "type": "Console"
#       },
#       {
#         "name": "Donkey Kong",
#         "type": "Game"
#       },
#       {
#         "name": "Nintendo",
#         "type": "Publisher"
#       }
#     ]
# 2025-05-11T16:02:07.535 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 835ms. StopReason: STOP. Tokens(in/out): 110/82
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      What company developed and published the games Mega Man 5 and Mega Man 11, and what year was each game released?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Mega Man 5",
#         "type": "Game"
#       },
#       {
#         "name": "Mega Man 11",
#         "type": "Game"
#       },
#       {
#         "name": "Capcom",
#         "type": "Publisher"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Mega Man 5",
#         "type": "Game"
#       },
#       {
#         "name": "Mega Man 11",
#         "type": "Game"
#       },
#       {
#         "name": "Capcom",
#         "type": "Publisher"
#       }
#     ]
# 2025-05-11T16:02:08.225 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 690ms. StopReason: STOP. Tokens(in/out): 110/55
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      What type of game is Street Fighter EX within the Street Fighter franchise, and when was the first game in the overall series released?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Street Fighter EX",
#         "type": "Game"
#       },
#       {
#         "name": "Street Fighter",
#         "type": "Game"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Street Fighter EX",
#         "type": "Game"
#       },
#       {
#         "name": "Street Fighter",
#         "type": "Game"
#       }
#     ]
# 2025-05-11T16:02:08.973 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 747ms. StopReason: STOP. Tokens(in/out): 116/81
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      Which Capcom-developed game, while borrowing elements from Resident Evil, is set in the Sengoku period and features a samurai protagonist named Samanosuke Akechi?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Onimusha: Warlords",
#         "type": "Game"
#       },
#       {
#         "name": "Resident Evil",
#         "type": "Game"
#       },
#       {
#         "name": "Capcom",
#         "type": "Publisher"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Onimusha: Warlords",
#         "type": "Game"
#       },
#       {
#         "name": "Resident Evil",
#         "type": "Game"
#       },
#       {
#         "name": "Capcom",
#         "type": "Publisher"
#       }
#     ]
# 2025-05-11T16:02:09.569 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 595ms. StopReason: STOP. Tokens(in/out): 111/32
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      Which 1982 arcade game, inspired by Pac-Man, features a protagonist controlled by a joystick in a kitchen sink?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Pac-Man",
#         "type": "Game"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Pac-Man",
#         "type": "Game"
#       }
#     ]
# 2025-05-11T16:02:10.382 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 812ms. StopReason: STOP. Tokens(in/out): 99/98
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      In which Bowser games do players control Mario or Luigi to rescue Princess Peach?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Bowser",
#         "type": "Game"
#       },
#       {
#         "name": "Mario",
#         "type": "Game"
#       },
#       {
#         "name": "Luigi",
#         "type": "Game"
#       },
#       {
#         "name": "Princess Peach",
#         "type": "Game"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Bowser",
#         "type": "Game"
#       },
#       {
#         "name": "Mario",
#         "type": "Game"
#       },
#       {
#         "name": "Luigi",
#         "type": "Game"
#       },
#       {
#         "name": "Princess Peach",
#         "type": "Game"
#       }
#     ]
# 2025-05-11T16:02:11.171 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 788ms. StopReason: STOP. Tokens(in/out): 120/91
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      What type of game genre is associated with the Megami Tensei franchise, as demonstrated by Shin Megami Tensei III: Nocturne and Persona 4 Arena Ultimax?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Megami Tensei",
#         "type": "Game"
#       },
#       {
#         "name": "Shin Megami Tensei III: Nocturne",
#         "type": "Game"
#       },
#       {
#         "name": "Persona 4 Arena Ultimax",
#         "type": "Game"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Megami Tensei",
#         "type": "Game"
#       },
#       {
#         "name": "Shin Megami Tensei III: Nocturne",
#         "type": "Game"
#       },
#       {
#         "name": "Persona 4 Arena Ultimax",
#         "type": "Game"
#       }
#     ]
# 2025-05-11T16:02:11.897 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 725ms. StopReason: STOP. Tokens(in/out): 122/54
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      In which game, featuring a mixture of sports, are characters from the Dragon Quest series included alongside characters from other game series published by the company that merged with the original publisher of Dragon Quest?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Dragon Quest",
#         "type": "Game"
#       },
#       {
#         "name": "Square Enix",
#         "type": "Publisher"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Dragon Quest",
#         "type": "Game"
#       },
#       {
#         "name": "Square Enix",
#         "type": "Publisher"
#       }
#     ]
# 2025-05-11T16:02:12.552 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 654ms. StopReason: STOP. Tokens(in/out): 96/54
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      Which Star Wars games were developed and published by LucasArts?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Star Wars",
#         "type": "Game"
#       },
#       {
#         "name": "LucasArts",
#         "type": "Publisher"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Star Wars",
#         "type": "Game"
#       },
#       {
#         "name": "LucasArts",
#         "type": "Publisher"
#       }
#     ]
# 2025-05-11T16:02:13.404 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 851ms. StopReason: STOP. Tokens(in/out): 111/76
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      In which two Luigi games can you control Luigi as one of the main characters and work to stop Bowser from taking over the Mushroom World?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Luigi",
#         "type": "Game"
#       },
#       {
#         "name": "Bowser",
#         "type": "Game"
#       },
#       {
#         "name": "Mushroom World",
#         "type": "Game"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Luigi",
#         "type": "Game"
#       },
#       {
#         "name": "Bowser",
#         "type": "Game"
#       },
#       {
#         "name": "Mushroom World",
#         "type": "Game"
#       }
#     ]
# 2025-05-11T16:02:14.120 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 715ms. StopReason: STOP. Tokens(in/out): 106/75
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      Which Batman game series is based on a specific animated series and was published by multiple companies including Sega and Konami?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Batman",
#         "type": "Game"
#       },
#       {
#         "name": "Sega",
#         "type": "Publisher"
#       },
#       {
#         "name": "Konami",
#         "type": "Publisher"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Batman",
#         "type": "Game"
#       },
#       {
#         "name": "Sega",
#         "type": "Publisher"
#       },
#       {
#         "name": "Konami",
#         "type": "Publisher"
#       }
#     ]
# 2025-05-11T16:02:14.777 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 656ms. StopReason: STOP. Tokens(in/out): 103/58
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      How does Super Mario Bros. compare to Pole's Big Adventure in terms of game style?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Super Mario Bros.",
#         "type": "Game"
#       },
#       {
#         "name": "Pole's Big Adventure",
#         "type": "Game"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Super Mario Bros.",
#         "type": "Game"
#       },
#       {
#         "name": "Pole's Big Adventure",
#         "type": "Game"
#       }
#     ]
# 2025-05-11T16:02:15.658 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 880ms. StopReason: STOP. Tokens(in/out): 122/101
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      Which video game that was released in 1991 had Yoshiki Okamoto as a producer and also had a sequel released in 1997 that featured Ryu and Ken?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Street Fighter II",
#         "type": "Game"
#       },
#       {
#         "name": "Ryu",
#         "type": "Game"
#       },
#       {
#         "name": "Ken",
#         "type": "Game"
#       },
#       {
#         "name": "Yoshiki Okamoto",
#         "type": "Game"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Street Fighter II",
#         "type": "Game"
#       },
#       {
#         "name": "Ryu",
#         "type": "Game"
#       },
#       {
#         "name": "Ken",
#         "type": "Game"
#       },
#       {
#         "name": "Yoshiki Okamoto",
#         "type": "Game"
#       }
#     ]
# 2025-05-11T16:02:16.274 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 614ms. StopReason: STOP. Tokens(in/out): 101/54
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      What is the genre of game Metroid and in which crossover fighting game does it appear?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Metroid",
#         "type": "Game"
#       },
#       {
#         "name": "fighting game",
#         "type": "Game"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Metroid",
#         "type": "Game"
#       },
#       {
#         "name": "fighting game",
#         "type": "Game"
#       }
#     ]
# 2025-05-11T16:02:17.067 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 792ms. StopReason: STOP. Tokens(in/out): 101/55
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      What notable interaction was possible between Dance Dance Revolution and another rhythm game released by Konami?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Dance Dance Revolution",
#         "type": "Game"
#       },
#       {
#         "name": "Konami",
#         "type": "Publisher"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Dance Dance Revolution",
#         "type": "Game"
#       },
#       {
#         "name": "Konami",
#         "type": "Publisher"
#       }
#     ]
# 2025-05-11T16:02:17.735 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 667ms. StopReason: STOP. Tokens(in/out): 97/31
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      What type of game is Gradius based on the information provided?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Gradius",
#         "type": "Game"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Gradius",
#         "type": "Game"
#       }
#     ]
# 2025-05-11T16:02:18.638 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 902ms. StopReason: STOP. Tokens(in/out): 104/100
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      Which Tetris games, released on Nintendo platforms, were compatible with multiplayer accessories allowing multiple players to connect?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Tetris",
#         "type": "Game"
#       },
#       {
#         "name": "Nintendo",
#         "type": "Publisher"
#       },
#       {
#         "name": "Nintendo platforms",
#         "type": "Console"
#       },
#       {
#         "name": "multiplayer accessories",
#         "type": "Game"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Tetris",
#         "type": "Game"
#       },
#       {
#         "name": "Nintendo",
#         "type": "Publisher"
#       },
#       {
#         "name": "Nintendo platforms",
#         "type": "Console"
#       },
#       {
#         "name": "multiplayer accessories",
#         "type": "Game"
#       }
#     ]
# 2025-05-11T16:02:19.369 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 729ms. StopReason: STOP. Tokens(in/out): 100/79
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      How many game packs and expansion packs have been released for The Sims 4?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "The Sims 4",
#         "type": "Game"
#       },
#       {
#         "name": "game packs",
#         "type": "Game"
#       },
#       {
#         "name": "expansion packs",
#         "type": "Game"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "The Sims 4",
#         "type": "Game"
#       },
#       {
#         "name": "game packs",
#         "type": "Game"
#       },
#       {
#         "name": "expansion packs",
#         "type": "Game"
#       }
#     ]
# 2025-05-11T16:02:19.854 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 484ms. StopReason: STOP. Tokens(in/out): 98/31
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      In which game featuring Princess Peach is the main goal to rescue her?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Princess Peach",
#         "type": "Game"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Princess Peach",
#         "type": "Game"
#       }
#     ]
# 2025-05-11T16:02:20.486 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 631ms. StopReason: STOP. Tokens(in/out): 117/64
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      How did the commercial reception of a 1992 version of Mortal Kombat compare to the commercial reception of the 2011 version of Mortal Kombat?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Mortal Kombat (1992)",
#         "type": "Game"
#       },
#       {
#         "name": "Mortal Kombat (2011)",
#         "type": "Game"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Mortal Kombat (1992)",
#         "type": "Game"
#       },
#       {
#         "name": "Mortal Kombat (2011)",
#         "type": "Game"
#       }
#     ]
# 2025-05-11T16:02:21.037 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 550ms. StopReason: STOP. Tokens(in/out): 98/32
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      What is one way the game Virtua Fighter influenced other video games?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Virtua Fighter",
#         "type": "Game"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Virtua Fighter",
#         "type": "Game"
#       }
#     ]
# 2025-05-11T16:02:21.638 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 601ms. StopReason: STOP. Tokens(in/out): 105/31
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      Which games, featured in the Rare Replay compilation, were praised by critics for their graphics and gameplay variations?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Rare Replay",
#         "type": "Game"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Rare Replay",
#         "type": "Game"
#       }
#     ]
# 2025-05-11T16:02:22.453 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 814ms. StopReason: STOP. Tokens(in/out): 97/79
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      What similarities does Dynasty Warriors have with Dynasty Tactics and Demon Chaos?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Dynasty Warriors",
#         "type": "Game"
#       },
#       {
#         "name": "Dynasty Tactics",
#         "type": "Game"
#       },
#       {
#         "name": "Demon Chaos",
#         "type": "Game"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Dynasty Warriors",
#         "type": "Game"
#       },
#       {
#         "name": "Dynasty Tactics",
#         "type": "Game"
#       },
#       {
#         "name": "Demon Chaos",
#         "type": "Game"
#       }
#     ]
# 2025-05-11T16:02:23.095 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 641ms. StopReason: STOP. Tokens(in/out): 105/32
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      How did the Space Invaders franchise evolve beyond the original arcade game in terms of content and platform releases?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Space Invaders",
#         "type": "Game"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Space Invaders",
#         "type": "Game"
#       }
#     ]
# 2025-05-11T16:02:23.719 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 623ms. StopReason: STOP. Tokens(in/out): 113/54
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      Which Silent Hill related game, a playable teaser for a planned installment, was delisted from the PlayStation Store after the main game's cancellation?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Silent Hill",
#         "type": "Game"
#       },
#       {
#         "name": "PlayStation Store",
#         "type": "Console"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Silent Hill",
#         "type": "Game"
#       },
#       {
#         "name": "PlayStation Store",
#         "type": "Console"
#       }
#     ]
# 2025-05-11T16:02:24.489 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 769ms. StopReason: STOP. Tokens(in/out): 104/32
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      Besides the release date of Castlevania Judgment, what other release date was strategically not overshadowed by it?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Castlevania Judgment",
#         "type": "Game"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Castlevania Judgment",
#         "type": "Game"
#       }
#     ]
# 2025-05-11T16:02:25.199 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 709ms. StopReason: STOP. Tokens(in/out): 101/59
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      Which Spider-Man game is a sequel and features an extraterrestrial symbiote?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Spider-Man",
#         "type": "Game"
#       },
#         {
#         "name": "extraterrestrial symbiote",
#         "type": "Game"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Spider-Man",
#         "type": "Game"
#       },
#       {
#         "name": "extraterrestrial symbiote",
#         "type": "Game"
#       }
#     ]
# 2025-05-11T16:02:25.868 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 668ms. StopReason: STOP. Tokens(in/out): 100/60
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      In which game featuring characters from Assassin's Creed can Ezio be played?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Assassin's Creed",
#         "type": "Game"
#       },
#       {
#         "name": "Ezio Auditore da Firenze",
#         "type": "Game"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Assassin's Creed",
#         "type": "Game"
#       },
#       {
#         "name": "Ezio Auditore da Firenze",
#         "type": "Game"
#       }
#     ]
# 2025-05-11T16:02:26.656 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 787ms. StopReason: STOP. Tokens(in/out): 111/89
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      What abilities and equipment does Link utilize in The Legend of Zelda: A Link Between Worlds and The Legend of Zelda: Skyward Sword?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "The Legend of Zelda: A Link Between Worlds",
#         "type": "Game"
#       },
#       {
#         "name": "The Legend of Zelda: Skyward Sword",
#         "type": "Game"
#       },
#       {
#         "name": "Link",
#         "type": "Game"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "The Legend of Zelda: A Link Between Worlds",
#         "type": "Game"
#       },
#       {
#         "name": "The Legend of Zelda: Skyward Sword",
#         "type": "Game"
#       },
#       {
#         "name": "Link",
#         "type": "Game"
#       }
#     ]
# 2025-05-11T16:02:27.327 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 670ms. StopReason: STOP. Tokens(in/out): 114/56
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      Which Fire Emblem game features strategic maps and character dialogue to tell its story and was rereleased in Japan as part of the Classic SNES Edition?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Fire Emblem",
#         "type": "Game"
#       },
#       {
#         "name": "Super Nintendo Entertainment System",
#         "type": "Console"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Fire Emblem",
#         "type": "Game"
#       },
#       {
#         "name": "Super Nintendo Entertainment System",
#         "type": "Console"
#       }
#     ]
# 2025-05-11T16:02:27.829 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 501ms. StopReason: STOP. Tokens(in/out): 106/35
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      What is a gameplay mechanic in the game Puyo Puyo 2 that was experimental but became widely successful?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Puyo Puyo 2",
#         "type": "Game"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Puyo Puyo 2",
#         "type": "Game"
#       }
#     ]
# 2025-05-11T16:02:28.534 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 704ms. StopReason: STOP. Tokens(in/out): 111/77
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      Which God of War game is the fastest-selling first-party launch week in PlayStation history and features Kratos alongside his teenage son?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "God of War",
#         "type": "Game"
#       },
#       {
#         "name": "PlayStation",
#         "type": "Console"
#       },
#       {
#         "name": "Kratos",
#         "type": "Game"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "God of War",
#         "type": "Game"
#       },
#       {
#         "name": "PlayStation",
#         "type": "Console"
#       },
#       {
#         "name": "Kratos",
#         "type": "Game"
#       }
#     ]
# 2025-05-11T16:02:29.098 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 563ms. StopReason: STOP. Tokens(in/out): 105/32
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      In which games is Doctor Eggman either the main antagonist or was a character that influenced a main antagonist?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Doctor Eggman",
#         "type": "Game"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Doctor Eggman",
#         "type": "Game"
#       }
#     ]
# 2025-05-11T16:02:29.837 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 738ms. StopReason: STOP. Tokens(in/out): 110/61
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      What feature that is in New Super Mario Bros. Wii did not make it into Super Mario 64 because of hardware limitations?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "New Super Mario Bros. Wii",
#         "type": "Game"
#       },
#       {
#         "name": "Super Mario 64",
#         "type": "Game"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "New Super Mario Bros. Wii",
#         "type": "Game"
#       },
#       {
#         "name": "Super Mario 64",
#         "type": "Game"
#       }
#     ]
# 2025-05-11T16:02:30.583 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 745ms. StopReason: STOP. Tokens(in/out): 109/56
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      Which game, besides Phantasy Star Online titles, was one of the few games designed for online play on the GameCube?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Phantasy Star Online",
#         "type": "Game"
#       },
#       {
#         "name": "GameCube",
#         "type": "Console"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Phantasy Star Online",
#         "type": "Game"
#       },
#       {
#         "name": "GameCube",
#         "type": "Console"
#       }
#     ]
# 2025-05-11T16:02:31.179 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 595ms. StopReason: STOP. Tokens(in/out): 99/55
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      Which Dragon Ball creator also provided artwork and character designs for Dragon Quest VII?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Dragon Ball",
#         "type": "Game"
#       },
#       {
#         "name": "Dragon Quest VII",
#         "type": "Game"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Dragon Ball",
#         "type": "Game"
#       },
#       {
#         "name": "Dragon Quest VII",
#         "type": "Game"
#       }
#     ]
# 2025-05-11T16:02:31.924 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 744ms. StopReason: STOP. Tokens(in/out): 98/76
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      What are two spin-off Pokémon games released on different Nintendo consoles?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Pokémon",
#         "type": "Game"
#       },
#       {
#         "name": "Nintendo",
#         "type": "Publisher"
#       },
#       {
#         "name": "Nintendo Consoles",
#         "type": "Console"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Pokémon",
#         "type": "Game"
#       },
#       {
#         "name": "Nintendo",
#         "type": "Publisher"
#       },
#       {
#         "name": "Nintendo Consoles",
#         "type": "Console"
#       }
#     ]
# 2025-05-11T16:02:32.926 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 1000ms. StopReason: STOP. Tokens(in/out): 110/139
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      Which companies developed the first two Super Smash Bros. games compared to Super Smash Bros. for Nintendo 3DS and Wii U?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Super Smash Bros.",
#         "type": "Game"
#       },
#       {
#         "name": "Super Smash Bros. Melee",
#         "type": "Game"
#       },
#       {
#         "name": "Super Smash Bros. for Nintendo 3DS and Wii U",
#         "type": "Game"
#       },
#       {
#         "name": "Nintendo 3DS",
#         "type": "Console"
#       },
#       {
#         "name": "Wii U",
#         "type": "Console"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Super Smash Bros.",
#         "type": "Game"
#       },
#       {
#         "name": "Super Smash Bros. Melee",
#         "type": "Game"
#       },
#       {
#         "name": "Super Smash Bros. for Nintendo 3DS and Wii U",
#         "type": "Game"
#       },
#       {
#         "name": "Nintendo 3DS",
#         "type": "Console"
#       },
#       {
#         "name": "Wii U",
#         "type": "Console"
#       }
#     ]
# 2025-05-11T16:02:33.557 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 630ms. StopReason: STOP. Tokens(in/out): 115/60
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      What are the differences in development responsibility and key personnel between the 1998 Metal Gear Solid and the upcoming Metal Gear Solid Delta: Snake Eater?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Metal Gear Solid",
#         "type": "Game"
#       },
#       {
#         "name": "Metal Gear Solid Delta: Snake Eater",
#         "type": "Game"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Metal Gear Solid",
#         "type": "Game"
#       },
#       {
#         "name": "Metal Gear Solid Delta: Snake Eater",
#         "type": "Game"
#       }
#     ]
# 2025-05-11T16:02:34.207 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 649ms. StopReason: STOP. Tokens(in/out): 111/57
#     ---PROMPT---
# ...
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      What period in real-world history serves as the setting for the main narrative of Assassin's Creed II, and was this game the first installment in the series to break the trend of yearly releases?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Assassin's Creed II",
#         "type": "Game"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Assassin's Creed II",
#         "type": "Game"
#       }
#     ]
# 2025-05-11T16:03:03.234 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 658ms. StopReason: STOP. Tokens(in/out): 102/54
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      Which company developed Metal Slug after its graphic designers previously worked on other titles at Irem?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Metal Slug",
#         "type": "Game"
#       },
#       {
#         "name": "Irem",
#         "type": "Publisher"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Metal Slug",
#         "type": "Game"
#       },
#       {
#         "name": "Irem",
#         "type": "Publisher"
#       }
#     ]
# 2025-05-11T16:03:03.867 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 631ms. StopReason: STOP. Tokens(in/out): 105/60
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      What gameplay mechanics does Kirby's Dream Land introduce that are later used in Kirby's Dream Buffet?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Kirby's Dream Land",
#         "type": "Game"
#       },
#       {
#         "name": "Kirby's Dream Buffet",
#         "type": "Game"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Kirby's Dream Land",
#         "type": "Game"
#       },
#       {
#         "name": "Kirby's Dream Buffet",
#         "type": "Game"
#       }
#     ]
# 2025-05-11T16:03:04.472 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 604ms. StopReason: STOP. Tokens(in/out): 106/31
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      What was Sonic Adventure's original release year, and with what other game did it share a key developer?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Sonic Adventure",
#         "type": "Game"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Sonic Adventure",
#         "type": "Game"
#       }
#     ]
# 2025-05-11T16:03:05.157 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 684ms. StopReason: STOP. Tokens(in/out): 99/34
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      What other game has a similar gameplay style to Super Smash Bros. Melee?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Super Smash Bros. Melee",
#         "type": "Game"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Super Smash Bros. Melee",
#         "type": "Game"
#       }
#     ]
# 2025-05-11T16:03:05.685 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 528ms. StopReason: STOP. Tokens(in/out): 99/32
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      Is Life & Death a life simulation video game or a surgery simulation game?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Life & Death",
#         "type": "Game"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Life & Death",
#         "type": "Game"
#       }
#     ]
# 2025-05-11T16:03:06.585 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 899ms. StopReason: STOP. Tokens(in/out): 107/104
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      Which *Ratchet & Clank* titles are available on PlayStation consoles other than PlayStation 2 and 3?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Ratchet & Clank",
#         "type": "Game"
#       },
#       {
#         "name": "PlayStation 2",
#         "type": "Console"
#       },
#       {
#         "name": "PlayStation 3",
#         "type": "Console"
#       },
#       {
#         "name": "PlayStation",
#         "type": "Console"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Ratchet & Clank",
#         "type": "Game"
#       },
#       {
#         "name": "PlayStation 2",
#         "type": "Console"
#       },
#       {
#         "name": "PlayStation 3",
#         "type": "Console"
#       },
#       {
#         "name": "PlayStation",
#         "type": "Console"
#       }
#     ]
# 2025-05-11T16:03:07.370 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 784ms. StopReason: STOP. Tokens(in/out): 121/83
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      What type of game genres, aside from RPGs, has the Persona series expanded into, and which game designer who worked on Persona also worked on Stella Deus: The Gate of Eternity?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Persona",
#         "type": "Game"
#       },
#       {
#         "name": "Role-Playing Game",
#         "type": "Game"
#       },
#       {
#         "name": "Stella Deus: The Gate of Eternity",
#         "type": "Game"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Persona",
#         "type": "Game"
#       },
#       {
#         "name": "Role-Playing Game",
#         "type": "Game"
#       },
#       {
#         "name": "Stella Deus: The Gate of Eternity",
#         "type": "Game"
#       }
#     ]
# 2025-05-11T16:03:08.095 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 724ms. StopReason: STOP. Tokens(in/out): 100/77
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      What other racing game developed and published by Nintendo was compared to F-Zero?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "racing game",
#         "type": "Game"
#       },
#       {
#         "name": "Nintendo",
#         "type": "Publisher"
#       },
#       {
#         "name": "F-Zero",
#         "type": "Game"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "racing game",
#         "type": "Game"
#       },
#       {
#         "name": "Nintendo",
#         "type": "Publisher"
#       },
#       {
#         "name": "F-Zero",
#         "type": "Game"
#       }
#     ]
# 2025-05-11T16:03:08.764 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 668ms. StopReason: STOP. Tokens(in/out): 101/53
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      Which Rock Band games are band-centric and which incorporate elements of Lego video games?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Rock Band",
#         "type": "Game"
#       },
#       {
#         "name": "Lego",
#         "type": "Game"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Rock Band",
#         "type": "Game"
#       },
#       {
#         "name": "Lego",
#         "type": "Game"
#       }
#     ]
# 2025-05-11T16:03:09.537 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 771ms. StopReason: STOP. Tokens(in/out): 143/77
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      Which Mario franchise game is a compilation of minigames from home console installments and was released for the Nintendo 3DS in North America in November 2017, while another game in the franchise featuring Luigi as the main character was released for the same console in 2018?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Mario",
#         "type": "Game"
#       },
#       {
#         "name": "Nintendo 3DS",
#         "type": "Console"
#       },
#       {
#         "name": "Luigi",
#         "type": "Game"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Mario",
#         "type": "Game"
#       },
#       {
#         "name": "Nintendo 3DS",
#         "type": "Console"
#       },
#       {
#         "name": "Luigi",
#         "type": "Game"
#       }
#     ]
# 2025-05-11T16:03:10.194 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 656ms. StopReason: STOP. Tokens(in/out): 97/57
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      Was God of War III originally released on the PlayStation 3?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "God of War III",
#         "type": "Game"
#       },
#       {
#         "name": "PlayStation 3",
#         "type": "Console"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "God of War III",
#         "type": "Game"
#       },
#       {
#         "name": "PlayStation 3",
#         "type": "Console"
#       }
#     ]
# 2025-05-11T16:03:10.703 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 508ms. StopReason: STOP. Tokens(in/out): 109/31
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      Which video games, besides Asteroids, used the "rotate-and-thrust" control scheme or were inspired by it?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Asteroids",
#         "type": "Game"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Asteroids",
#         "type": "Game"
#       }
#     ]
# 2025-05-11T16:03:11.381 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 677ms. StopReason: STOP. Tokens(in/out): 102/58
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      What are some specific connections between Bubble Bobble and the game Puzzle Bobble 2?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Bubble Bobble",
#         "type": "Game"
#       },
#       {
#         "name": "Puzzle Bobble 2",
#         "type": "Game"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Bubble Bobble",
#         "type": "Game"
#       },
#       {
#         "name": "Puzzle Bobble 2",
#         "type": "Game"
#       }
#     ]
# 2025-05-11T16:03:12.200 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 818ms. StopReason: STOP. Tokens(in/out): 107/87
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      When did Phantasy Star Online 2: New Genesis release worldwide on Xbox One and Xbox Series X/S?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Phantasy Star Online 2: New Genesis",
#         "type": "Game"
#       },
#       {
#         "name": "Xbox One",
#         "type": "Console"
#       },
#       {
#         "name": "Xbox Series X/S",
#         "type": "Console"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Phantasy Star Online 2: New Genesis",
#         "type": "Game"
#       },
#       {
#         "name": "Xbox One",
#         "type": "Console"
#       },
#       {
#         "name": "Xbox Series X/S",
#         "type": "Console"
#       }
#     ]

# %%
questions_df['entities'] = entities

# %%
questions_df['entities'] = questions_df['entities'].apply(
    lambda x: {
        k: [match_entity(v, k) for v in v]
        for k,v in x.items()
        if v is not None
    }
)

# %%
questions_df["question_embedding"] = generate_embeddings(questions_df.question.tolist())

# %%
questions_df.to_parquet("../../data/retrieval_questions_multichunks.parquet", index=False)

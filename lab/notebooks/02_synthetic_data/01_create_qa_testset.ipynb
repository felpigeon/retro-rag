# %% [markdown]
# # Generation d'un ensemble de test pour le pipeline end-to-end
#
# 1. Les questions ont ete generees avec DeepSeek-R1 (50%) et GeminiPro 2.5 (50%)
# 2. Les reponses sont generees avec GeminiFlash 2.5 en faisant des recherches sur le web
# 3. Les entitees des questions sont extraites
# 4. Les embeddings des questions sont ajoutes

# %%
import pandas as pd
import yaml
import time

from google import genai
from google.genai.types import Tool, GenerateContentConfig, GoogleSearch

# %%
import sys
sys.path.append('../../src')

from entity import extract_entities, match_entity
from embeddings import generate_embeddings

# %% [markdown]
# # 1. Chargement des questions

# %%
with open('questions.yml', 'r') as file:
    data = yaml.safe_load(file)

# %%
questions = []

for k in data:
    for level in data[k]:
        _questions = data[k][level].splitlines()

        questions += [
            (k, level, q.strip())
            for q in _questions
        ]

df = pd.DataFrame(questions, columns=['source', 'level', 'question'])

# %% [markdown]
# ## 2. Generation des reponses
#
# Gemini2.5 Flash fait des recherches sur le web, en mode 'reasoning'
#   - Il y a trois difficultes de reponse: facile, moyen, difficile

# %%
import os

client = genai.Client(api_key=os.environ.get("GOOGLE_API_KEY"))
model_id = "gemini-2.5-flash-preview-04-17"

# %%
system_prompt = """You are helping me creating a ground truth for a question-answering task.
Search the web and find the answer to the question.
Be as consice as possible: do not add additional information.

Example:
Q: What is the capital of France?
A: The capital of France is Paris."""

# %%
def generate_answer(question):
    google_search_tool = Tool(
        google_search = GoogleSearch()
    )

    response = client.models.generate_content(
        model=model_id,
        contents=question,
        config=GenerateContentConfig(
            tools=[google_search_tool],
            response_modalities=["TEXT"],
            system_instruction=system_prompt,
        )
    )

    return response.candidates[0].content.parts[0].text

# %%
answers = {}

# %%
for i, row in df.iterrows():
    if i in answers: continue

    start = time.time()
    answers[i] = generate_answer(row.question)

    time.sleep(max(0, 7 - (time.time() - start)))  # Avoid rate limits

# %%
answers_df = pd.DataFrame(answers.items(), columns=['index', 'answer'])
answers_df = answers_df.set_index('index')

# %%
df = df.join(answers_df)

# %% [markdown]
# # 3. Extraction des entitees dans les questions

# %%
df['entities'] = df.question.apply(extract_entities, sleep=7)
# Out:
# 2025-05-12T18:18:37.794 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 715ms. StopReason: STOP. Tokens(in/out): 99/32
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      What year was the Nintendo Entertainment System (NES) released in North America?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Nintendo Entertainment System",
#         "type": "Console"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Nintendo Entertainment System",
#         "type": "Console"
#       }
#     ]
# 2025-05-12T18:18:45.534 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 738ms. StopReason: STOP. Tokens(in/out): 92/32
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      Who developed the game Pac-Man?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Pac-Man",
#         "type": "Game"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Pac-Man",
#         "type": "Game"
#       }
#     ]
# 2025-05-12T18:18:53.200 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 665ms. StopReason: STOP. Tokens(in/out): 96/54
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      On which console was the game Sonic the Hedgehog first released?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Sonic the Hedgehog",
#         "type": "Game"
#       },
#       {
#         "name": "Console",
#         "type": "Console"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Sonic the Hedgehog",
#         "type": "Game"
#       },
#       {
#         "name": "Console",
#         "type": "Console"
#       }
#     ]
# 2025-05-12T18:19:00.962 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 760ms. StopReason: STOP. Tokens(in/out): 100/56
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      What was the flagship fighting game for the Super Nintendo Entertainment System (SNES)?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Super Nintendo Entertainment System",
#         "type": "Console"
#       },
#       {
#         "name": "fighting game",
#         "type": "Game"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Super Nintendo Entertainment System",
#         "type": "Console"
#       },
#       {
#         "name": "fighting game",
#         "type": "Game"
#       }
#     ]
# 2025-05-12T18:19:08.603 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 640ms. StopReason: STOP. Tokens(in/out): 95/59
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      Which company created the Atari 2600?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Atari 2600",
#         "type": "Console"
#       },
#       {
#         "name": "Atari",
#         "type": "Publisher"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Atari 2600",
#         "type": "Console"
#       },
#       {
#         "name": "Atari",
#         "type": "Publisher"
#       }
#     ]
# 2025-05-12T18:19:16.237 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 633ms. StopReason: STOP. Tokens(in/out): 95/31
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      What is the main objective in the game Donkey Kong?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Donkey Kong",
#         "type": "Game"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Donkey Kong",
#         "type": "Game"
#       }
#     ]
# 2025-05-12T18:19:24.057 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 819ms. StopReason: STOP. Tokens(in/out): 96/54
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      Name a popular RPG game released for the PlayStation 1.
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "RPG",
#         "type": "Game"
#       },
#       {
#         "name": "PlayStation 1",
#         "type": "Console"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "RPG",
#         "type": "Game"
#       },
#       {
#         "name": "PlayStation 1",
#         "type": "Console"
#       }
#     ]
# 2025-05-12T18:19:32.064 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 1006ms. StopReason: STOP. Tokens(in/out): 101/77
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      What was the name of Sega's handheld console that competed with the Game Boy?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Sega",
#         "type": "Publisher"
#       },
#       {
#         "name": "Game Boy",
#         "type": "Console"
#       },
#       {
#         "name": "handheld console",
#         "type": "Console"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Sega",
#         "type": "Publisher"
#       },
#       {
#         "name": "Game Boy",
#         "type": "Console"
#       },
#       {
#         "name": "handheld console",
#         "type": "Console"
#       }
#     ]
# 2025-05-12T18:19:39.565 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 500ms. StopReason: STOP. Tokens(in/out): 95/30
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      Which magazine often featured cheat codes for games like Contra?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Contra",
#         "type": "Game"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Contra",
#         "type": "Game"
#       }
#     ]
# 2025-05-12T18:19:47.180 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 614ms. StopReason: STOP. Tokens(in/out): 96/31
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      What was the best-selling game on the Sega Genesis?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Sega Genesis",
#         "type": "Console"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Sega Genesis",
#         "type": "Console"
#       }
#     ]
# 2025-05-12T18:19:55.071 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 890ms. StopReason: STOP. Tokens(in/out): 97/57
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      Who is the main character in The Legend of Zelda on NES?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "The Legend of Zelda",
#         "type": "Game"
#       },
#       {
#         "name": "Nintendo Entertainment System",
#         "type": "Console"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "The Legend of Zelda",
#         "type": "Game"
#       },
#       {
#         "name": "Nintendo Entertainment System",
#         "type": "Console"
#       }
#     ]
# 2025-05-12T18:20:02.637 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 565ms. StopReason: STOP. Tokens(in/out): 91/31
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      What type of game is Tetris?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Tetris",
#         "type": "Game"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Tetris",
#         "type": "Game"
#       }
#     ]
# 2025-05-12T18:20:10.288 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 650ms. StopReason: STOP. Tokens(in/out): 92/52
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      Which console first introduced the character Mario?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Mario",
#         "type": "Game"
#       },
#       {
#         "name": "Console",
#         "type": "Console"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Mario",
#         "type": "Game"
#       },
#       {
#         "name": "Console",
#         "type": "Console"
#       }
#     ]
# 2025-05-12T18:20:17.818 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 529ms. StopReason: STOP. Tokens(in/out): 98/34
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      What was the storage medium for games on the Commodore 64?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Commodore 64",
#         "type": "Console"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Commodore 64",
#         "type": "Console"
#       }
#     ]
# 2025-05-12T18:20:25.388 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 569ms. StopReason: STOP. Tokens(in/out): 95/33
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      Name a launch title for the Nintendo 64.
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Nintendo 64",
#         "type": "Console"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Nintendo 64",
#         "type": "Console"
#       }
#     ]
# 2025-05-12T18:20:33.054 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 665ms. StopReason: STOP. Tokens(in/out): 93/32
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      What company published the game Street Fighter II?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Street Fighter II",
#         "type": "Game"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Street Fighter II",
#         "type": "Game"
#       }
#     ]
# 2025-05-12T18:20:40.790 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 735ms. StopReason: STOP. Tokens(in/out): 101/56
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      Which console is known for the game Alex Kidd in Miracle World being built-in?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Alex Kidd in Miracle World",
#         "type": "Game"
#       },
#       {
#         "name": "console",
#         "type": "Console"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Alex Kidd in Miracle World",
#         "type": "Game"
#       },
#       {
#         "name": "console",
#         "type": "Console"
#       }
#     ]
# 2025-05-12T18:20:48.553 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 761ms. StopReason: STOP. Tokens(in/out): 96/54
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      What was the primary controller like for the ColecoVision?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "ColecoVision",
#         "type": "Console"
#       },
#       {
#         "name": "controller",
#         "type": "Console"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "ColecoVision",
#         "type": "Console"
#       },
#       {
#         "name": "controller",
#         "type": "Console"
#       }
#     ]
# 2025-05-12T18:20:56.339 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 785ms. StopReason: STOP. Tokens(in/out): 105/54
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      What was the name of the add-on for the Sega Genesis that allowed it to play CD games?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Sega Genesis",
#         "type": "Console"
#       },
#       {
#         "name": "Sega CD",
#         "type": "Console"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Sega Genesis",
#         "type": "Console"
#       },
#       {
#         "name": "Sega CD",
#         "type": "Console"
#       }
#     ]
# 2025-05-12T18:21:03.973 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 633ms. StopReason: STOP. Tokens(in/out): 97/32
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      In what year was Space Invaders first released in arcades?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Space Invaders",
#         "type": "Game"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Space Invaders",
#         "type": "Game"
#       }
#     ]
# 2025-05-12T18:21:11.744 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 770ms. StopReason: STOP. Tokens(in/out): 97/32
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      What were common criticisms of the Atari Jaguar's game library?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Atari Jaguar",
#         "type": "Console"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Atari Jaguar",
#         "type": "Console"
#       }
#     ]
# 2025-05-12T18:21:19.482 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 737ms. StopReason: STOP. Tokens(in/out): 104/77
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      How did the graphics of Doom on the SNES compare to the PC version, according to contemporary reviews?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Doom",
#         "type": "Game"
#       },
#       {
#         "name": "Super Nintendo Entertainment System",
#         "type": "Console"
#       },
#       {
#         "name": "PC",
#         "type": "Console"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Doom",
#         "type": "Game"
#       },
#       {
#         "name": "Super Nintendo Entertainment System",
#         "type": "Console"
#       },
#       {
#         "name": "PC",
#         "type": "Console"
#       }
#     ]
# 2025-05-12T18:21:27.055 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 571ms. StopReason: STOP. Tokens(in/out): 99/53
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      What kind of influence did the game Chrono Trigger have on subsequent RPGs?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Chrono Trigger",
#         "type": "Game"
#       },
#       {
#         "name": "RPG",
#         "type": "Game"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Chrono Trigger",
#         "type": "Game"
#       },
#       {
#         "name": "RPG",
#         "type": "Game"
#       }
#     ]
# 2025-05-12T18:21:34.801 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 745ms. StopReason: STOP. Tokens(in/out): 102/35
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      Describe the atmosphere and themes often explored in games for the TurboGrafx-16.
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "TurboGrafx-16",
#         "type": "Console"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "TurboGrafx-16",
#         "type": "Console"
#       }
#     ]
# 2025-05-12T18:21:42.636 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 833ms. StopReason: STOP. Tokens(in/out): 100/74
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      What were some of the marketing strategies Sega used to promote the Genesis against Nintendo?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Genesis",
#         "type": "Console"
#       },
#       {
#         "name": "Sega",
#         "type": "Publisher"
#       },
#       {
#         "name": "Nintendo",
#         "type": "Publisher"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Genesis",
#         "type": "Console"
#       },
#       {
#         "name": "Sega",
#         "type": "Publisher"
#       },
#       {
#         "name": "Nintendo",
#         "type": "Publisher"
#       }
#     ]
# 2025-05-12T18:21:50.244 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 607ms. StopReason: STOP. Tokens(in/out): 99/31
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      How did magazines of the era describe the sound capabilities of the Neo Geo?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Neo Geo",
#         "type": "Console"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Neo Geo",
#         "type": "Console"
#       }
#     ]
# 2025-05-12T18:21:57.792 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 547ms. StopReason: STOP. Tokens(in/out): 101/31
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      What were some of the technical challenges developers faced when creating games for the Sega Saturn?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Sega Saturn",
#         "type": "Console"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Sega Saturn",
#         "type": "Console"
#       }
#     ]
# 2025-05-12T18:22:05.417 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 623ms. StopReason: STOP. Tokens(in/out): 106/31
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      What was the public perception of the Virtual Boy at the time of its release, as reflected in gaming magazines?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Virtual Boy",
#         "type": "Console"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Virtual Boy",
#         "type": "Console"
#       }
#     ]
# 2025-05-12T18:22:13.210 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 792ms. StopReason: STOP. Tokens(in/out): 112/60
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      How did the gameplay of GoldenEye 007 on the Nintendo 64 revolutionize the first-person shooter genre on consoles?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "GoldenEye 007",
#         "type": "Game"
#       },
#       {
#         "name": "Nintendo 64",
#         "type": "Console"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "GoldenEye 007",
#         "type": "Game"
#       },
#       {
#         "name": "Nintendo 64",
#         "type": "Console"
#       }
#     ]
# 2025-05-12T18:22:20.774 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 563ms. StopReason: STOP. Tokens(in/out): 103/31
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      What were some of the unique accessories available for the original Game Boy and how were they reviewed?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Game Boy",
#         "type": "Console"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Game Boy",
#         "type": "Console"
#       }
#     ]
# 2025-05-12T18:22:28.436 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 661ms. StopReason: STOP. Tokens(in/out): 102/33
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      What was the critical reception of the 3DO Interactive Multiplayer console's launch titles?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "3DO Interactive Multiplayer",
#         "type": "Console"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "3DO Interactive Multiplayer",
#         "type": "Console"
#       }
#     ]
# 2025-05-12T18:22:36.035 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 597ms. StopReason: STOP. Tokens(in/out): 105/56
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      How did game magazines compare the controller design of the Nintendo 64 to that of the Sony PlayStation?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Nintendo 64",
#         "type": "Console"
#       },
#       {
#         "name": "Sony PlayStation",
#         "type": "Console"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Nintendo 64",
#         "type": "Console"
#       },
#       {
#         "name": "Sony PlayStation",
#         "type": "Console"
#       }
#     ]
# 2025-05-12T18:22:43.647 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 611ms. StopReason: STOP. Tokens(in/out): 107/31
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      What were some of the most innovative gameplay mechanics introduced in Amiga games during the late 1980s?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Amiga",
#         "type": "Console"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Amiga",
#         "type": "Console"
#       }
#     ]
# 2025-05-12T18:22:51.166 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 518ms. StopReason: STOP. Tokens(in/out): 109/31
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      What was the impact of the ESRB rating system's introduction on the content of games like Mortal Kombat for home consoles?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Mortal Kombat",
#         "type": "Game"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Mortal Kombat",
#         "type": "Game"
#       }
#     ]
# 2025-05-12T18:22:58.816 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 650ms. StopReason: STOP. Tokens(in/out): 99/31
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      How did magazines explain the "blast processing" feature of the Sega Genesis?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Sega Genesis",
#         "type": "Console"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Sega Genesis",
#         "type": "Console"
#       }
#     ]
# 2025-05-12T18:23:06.531 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 713ms. StopReason: STOP. Tokens(in/out): 100/54
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      What were reviewers saying about the narrative complexity of Final Fantasy VII on the PlayStation?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Final Fantasy VII",
#         "type": "Game"
#       },
#       {
#         "name": "PlayStation",
#         "type": "Console"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Final Fantasy VII",
#         "type": "Game"
#       },
#       {
#         "name": "PlayStation",
#         "type": "Console"
#       }
#     ]
# 2025-05-12T18:23:14.142 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 610ms. StopReason: STOP. Tokens(in/out): 106/56
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      How was the level design in Super Mario 64 perceived as a shift from 2D Mario games?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Super Mario 64",
#         "type": "Game"
#       },
#       {
#         "name": "Mario",
#         "type": "Game"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Super Mario 64",
#         "type": "Game"
#       },
#       {
#         "name": "Mario",
#         "type": "Game"
#       }
#     ]
# 2025-05-12T18:23:21.938 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 795ms. StopReason: STOP. Tokens(in/out): 123/55
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      What were the main arguments in magazine articles discussing the "bit wars" (e.g., 16-bit vs 32-bit) between consoles like the SNES and PlayStation?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Super Nintendo Entertainment System",
#         "type": "Console"
#       },
#       {
#         "name": "PlayStation",
#         "type": "Console"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Super Nintendo Entertainment System",
#         "type": "Console"
#       },
#       {
#         "name": "PlayStation",
#         "type": "Console"
#       }
#     ]
# 2025-05-12T18:23:29.685 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 746ms. StopReason: STOP. Tokens(in/out): 108/53
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      What kind of community or modding scene was discussed in magazines for PC games like Quake in the mid-90s?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Quake",
#         "type": "Game"
#       },
#       {
#         "name": "PC",
#         "type": "Console"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Quake",
#         "type": "Game"
#       },
#       {
#         "name": "PC",
#         "type": "Console"
#       }
#     ]
# 2025-05-12T18:23:37.508 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 822ms. StopReason: STOP. Tokens(in/out): 101/32
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      How did contemporary reviews assess the longevity and replay value of games for the Atari Lynx?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Atari Lynx",
#         "type": "Console"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Atari Lynx",
#         "type": "Console"
#       }
#     ]
# 2025-05-12T18:23:45.244 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 735ms. StopReason: STOP. Tokens(in/out): 110/62
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      Compare and contrast the critical reception and long-term impact of The Legend of Zelda: Ocarina of Time and Final Fantasy VII.
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "The Legend of Zelda: Ocarina of Time",
#         "type": "Game"
#       },
#       {
#         "name": "Final Fantasy VII",
#         "type": "Game"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "The Legend of Zelda: Ocarina of Time",
#         "type": "Game"
#       },
#       {
#         "name": "Final Fantasy VII",
#         "type": "Game"
#       }
#     ]
# 2025-05-12T18:23:53.303 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 1058ms. StopReason: STOP. Tokens(in/out): 106/77
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      Summarize the evolution of the fighting game genre as seen through key releases on the Neo Geo and Sega Saturn.
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "fighting game",
#         "type": "Game"
#       },
#       {
#         "name": "Neo Geo",
#         "type": "Console"
#       },
#       {
#         "name": "Sega Saturn",
#         "type": "Console"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "fighting game",
#         "type": "Game"
#       },
#       {
#         "name": "Neo Geo",
#         "type": "Console"
#       },
#       {
#         "name": "Sega Saturn",
#         "type": "Console"
#       }
#     ]
# 2025-05-12T18:24:00.930 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 625ms. StopReason: STOP. Tokens(in/out): 125/32
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      What were the primary factors contributing to the "video game crash of 1983," and how did the Nintendo Entertainment System subsequently revitalize the market, according to industry retrospectives in gaming magazines?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Nintendo Entertainment System",
#         "type": "Console"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Nintendo Entertainment System",
#         "type": "Console"
#       }
#     ]
# 2025-05-12T18:24:08.656 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 725ms. StopReason: STOP. Tokens(in/out): 126/79
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      Analyze the different approaches to 3D gaming taken by the Nintendo 64, Sony PlayStation, and Sega Saturn, highlighting the strengths and weaknesses of each console's design philosophy as discussed in period articles.
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Nintendo 64",
#         "type": "Console"
#       },
#       {
#         "name": "Sony PlayStation",
#         "type": "Console"
#       },
#       {
#         "name": "Sega Saturn",
#         "type": "Console"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Nintendo 64",
#         "type": "Console"
#       },
#       {
#         "name": "Sony PlayStation",
#         "type": "Console"
#       },
#       {
#         "name": "Sega Saturn",
#         "type": "Console"
#       }
#     ]
# 2025-05-12T18:24:16.429 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 771ms. StopReason: STOP. Tokens(in/out): 131/56
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      Trace the development of mascot platformers from the 8-bit era (e.g., Super Mario Bros., Sonic the Hedgehog) through the 32/64-bit era, discussing how gameplay and character design evolved.
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Super Mario Bros.",
#         "type": "Game"
#       },
#       {
#         "name": "Sonic the Hedgehog",
#         "type": "Game"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Super Mario Bros.",
#         "type": "Game"
#       },
#       {
#         "name": "Sonic the Hedgehog",
#         "type": "Game"
#       }
#     ]
# 2025-05-12T18:24:24.228 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 798ms. StopReason: STOP. Tokens(in/out): 124/60
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      Compare the launch strategies and initial game libraries of the Atari 2600 and the ColecoVision. What lessons can be learned from their respective successes and failures as documented in retro game publications?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Atari 2600",
#         "type": "Console"
#       },
#       {
#         "name": "ColecoVision",
#         "type": "Console"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Atari 2600",
#         "type": "Console"
#       },
#       {
#         "name": "ColecoVision",
#         "type": "Console"
#       }
#     ]
# 2025-05-12T18:24:31.872 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 643ms. StopReason: STOP. Tokens(in/out): 125/54
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      Discuss the portrayal of female protagonists in retro games like Metroid (Samus Aran) and Tomb Raider (Lara Croft) based on magazine articles from their respective eras. How has this perception changed in retrospective articles?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Metroid",
#         "type": "Game"
#       },
#       {
#         "name": "Tomb Raider",
#         "type": "Game"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Metroid",
#         "type": "Game"
#       },
#       {
#         "name": "Tomb Raider",
#         "type": "Game"
#       }
#     ]
# 2025-05-12T18:24:39.781 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 907ms. StopReason: STOP. Tokens(in/out): 125/101
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      What were the defining characteristics of "Western RPGs" versus "Japanese RPGs" on consoles like the SNES and PC during the 1990s, according to game reviews and feature articles?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Western RPG",
#         "type": "Game"
#       },
#       {
#         "name": "Japanese RPG",
#         "type": "Game"
#       },
#       {
#         "name": "Super Nintendo Entertainment System",
# ...
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "TurboGrafx-16",
#         "type": "Console"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "TurboGrafx-16",
#         "type": "Console"
#       }
#     ]
# 2025-05-12T18:32:07.272 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 985ms. StopReason: STOP. Tokens(in/out): 103/57
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      Compare the impact of Super Mario 64 and Tomb Raider on 3D camera systems.
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Super Mario 64",
#         "type": "Game"
#       },
#       {
#         "name": "Tomb Raider",
#         "type": "Game"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Super Mario 64",
#         "type": "Game"
#       },
#       {
#         "name": "Tomb Raider",
#         "type": "Game"
#       }
#     ]
# 2025-05-12T18:32:14.888 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 615ms. StopReason: STOP. Tokens(in/out): 105/54
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      How did the decline of arcades in the 1990s influence home console game design?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Arcades",
#         "type": "Game"
#       },
#       {
#         "name": "Home console",
#         "type": "Console"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Arcades",
#         "type": "Game"
#       },
#       {
#         "name": "Home console",
#         "type": "Console"
#       }
#     ]
# 2025-05-12T18:32:22.810 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 922ms. StopReason: STOP. Tokens(in/out): 105/106
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      Contrast the soundtracks of Mega Man 2 (NES) and Streets of Rage 2 (Genesis).
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Mega Man 2",
#         "type": "Game"
#       },
#       {
#         "name": "Nintendo Entertainment System",
#         "type": "Console"
#       },
#       {
#         "name": "Streets of Rage 2",
#         "type": "Game"
#       },
#       {
#         "name": "Sega Genesis",
#         "type": "Console"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Mega Man 2",
#         "type": "Game"
#       },
#       {
#         "name": "Nintendo Entertainment System",
#         "type": "Console"
#       },
#       {
#         "name": "Streets of Rage 2",
#         "type": "Game"
#       },
#       {
#         "name": "Sega Genesis",
#         "type": "Console"
#       }
#     ]
# 2025-05-12T18:32:30.545 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 734ms. StopReason: STOP. Tokens(in/out): 106/58
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      What design philosophies differentiate Donkey Kong Country’s pre-rendered graphics from Sonic 3’s sprite work?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Donkey Kong Country",
#         "type": "Game"
#       },
#       {
#         "name": "Sonic the Hedgehog 3",
#         "type": "Game"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Donkey Kong Country",
#         "type": "Game"
#       },
#       {
#         "name": "Sonic the Hedgehog 3",
#         "type": "Game"
#       }
#     ]
# 2025-05-12T18:32:38.538 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 992ms. StopReason: STOP. Tokens(in/out): 104/81
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      How did Half-Life on PC influence later console FPS titles like GoldenEye 007?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Half-Life",
#         "type": "Game"
#       },
#       {
#         "name": "PC",
#         "type": "Console"
#       },
#       {
#         "name": "GoldenEye 007",
#         "type": "Game"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Half-Life",
#         "type": "Game"
#       },
#       {
#         "name": "PC",
#         "type": "Console"
#       },
#       {
#         "name": "GoldenEye 007",
#         "type": "Game"
#       }
#     ]
# 2025-05-12T18:32:46.335 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 796ms. StopReason: STOP. Tokens(in/out): 100/57
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      Explain the long-term cultural impact of Pokémon Red/Blue on handheld gaming.
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Pokémon Red/Blue",
#         "type": "Game"
#       },
#       {
#         "name": "handheld gaming",
#         "type": "Console"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Pokémon Red/Blue",
#         "type": "Game"
#       },
#       {
#         "name": "handheld gaming",
#         "type": "Console"
#       }
#     ]
# 2025-05-12T18:32:54.069 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 733ms. StopReason: STOP. Tokens(in/out): 100/57
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      Compare the technical limitations of the Game Boy Advance to the Neo Geo Pocket Color.
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Game Boy Advance",
#         "type": "Console"
#       },
#       {
#         "name": "Neo Geo Pocket Color",
#         "type": "Console"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Game Boy Advance",
#         "type": "Console"
#       },
#       {
#         "name": "Neo Geo Pocket Color",
#         "type": "Console"
#       }
#     ]
# 2025-05-12T18:33:01.740 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 669ms. StopReason: STOP. Tokens(in/out): 99/32
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      Why did Final Fantasy Tactics receive mixed reviews initially but later gain cult status?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Final Fantasy Tactics",
#         "type": "Game"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Final Fantasy Tactics",
#         "type": "Game"
#       }
#     ]
# 2025-05-12T18:33:09.360 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 619ms. StopReason: STOP. Tokens(in/out): 97/31
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      How did EarthBound’s localization challenges affect its Western reception?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "EarthBound",
#         "type": "Game"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "EarthBound",
#         "type": "Game"
#       }
#     ]
# 2025-05-12T18:33:17.051 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 689ms. StopReason: STOP. Tokens(in/out): 109/31
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      Summarize the role of Myst in popularizing CD-ROM-based games in the 1990s.
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Myst",
#         "type": "Game"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Myst",
#         "type": "Game"
#       }
#     ]
# 2025-05-12T18:33:24.712 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 660ms. StopReason: STOP. Tokens(in/out): 104/60
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      Analyze the influence of Castlevania: Symphony of the Night on the “Metroidvania” genre.
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Castlevania: Symphony of the Night",
#         "type": "Game"
#       },
#       {
#         "name": "Metroidvania",
#         "type": "Game"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Castlevania: Symphony of the Night",
#         "type": "Game"
#       },
#       {
#         "name": "Metroidvania",
#         "type": "Game"
#       }
#     ]
# 2025-05-12T18:33:32.201 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 487ms. StopReason: STOP. Tokens(in/out): 99/32
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      How did the Sega Dreamcast’s online capabilities foreshadow modern gaming trends?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Sega Dreamcast",
#         "type": "Console"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Sega Dreamcast",
#         "type": "Console"
#       }
#     ]
# 2025-05-12T18:33:39.914 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 712ms. StopReason: STOP. Tokens(in/out): 101/78
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      Compare the longevity of Tetris (Game Boy) to Dr. Mario as puzzle games.
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "Tetris",
#         "type": "Game"
#       },
#       {
#         "name": "Game Boy",
#         "type": "Console"
#       },
#       {
#         "name": "Dr. Mario",
#         "type": "Game"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "Tetris",
#         "type": "Game"
#       },
#       {
#         "name": "Game Boy",
#         "type": "Console"
#       },
#       {
#         "name": "Dr. Mario",
#         "type": "Game"
#       }
#     ]
# 2025-05-12T18:33:47.683 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 768ms. StopReason: STOP. Tokens(in/out): 115/66
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      Why did E.T. the Extra-Terrestrial (Atari 2600) fail critically, and how did it affect the industry?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "E.T. the Extra-Terrestrial",
#         "type": "Game"
#       },
#       {
#         "name": "Atari 2600",
#         "type": "Console"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "E.T. the Extra-Terrestrial",
#         "type": "Game"
#       },
#       {
#         "name": "Atari 2600",
#         "type": "Console"
#       }
#     ]
# 2025-05-12T18:33:55.238 [BAML INFO] Function ExtractEntities:
#     Client: GeminiFlash (gemini-2.0-flash) - 554ms. StopReason: STOP. Tokens(in/out): 109/38
#     ---PROMPT---
#     user: Extract all the relevant entities from the user question on the video games and consonles domain.
#      - Resolve entities to their canonic form (example: LOTR -> Lord of the Rings).
#
#      User question:
#      How did The Legend of Zelda: Ocarina of Time’s Z-targeting system influence later 3D action games?
#
#     Answer with a JSON Array using this schema:
#     [
#       {
#         name: string,
#         type: 'Game' or 'Console' or 'Publisher',
#       }
#     ]
#
#     ---LLM REPLY---
#     ```json
#     [
#       {
#         "name": "The Legend of Zelda: Ocarina of Time",
#         "type": "Game"
#       }
#     ]
#     ```
#     ---Parsed Response (list<class Entity>)---
#     [
#       {
#         "name": "The Legend of Zelda: Ocarina of Time",
#         "type": "Game"
#       }
#     ]

# %%
df['entities'] = df['entities'].apply(
    lambda x: {
        k: [match_entity(v, k) for v in v]
        for k,v in x.items()
        if v is not None
    }
)

# %% [markdown]
# # 4. Generation des embeddings (pour la recherche semantique)

# %%
df['embeddings'] = generate_embeddings(df.question.tolist())

# %%
df
# Out:
#        source level                                           question  \
# 0      gemini  easy  What year was the Nintendo Entertainment Syste...
# 1      gemini  easy                    Who developed the game Pac-Man?
# 2      gemini  easy  On which console was the game Sonic the Hedgeh...
# 3      gemini  easy  What was the flagship fighting game for the Su...
# 4      gemini  easy              Which company created the Atari 2600?
# ..        ...   ...                                                ...
# 115  deepseek  hard  Analyze the influence of Castlevania: Symphony...
# 116  deepseek  hard  How did the Sega Dreamcast’s online capabiliti...
# 117  deepseek  hard  Compare the longevity of Tetris (Game Boy) to ...
# 118  deepseek  hard  Why did E.T. the Extra-Terrestrial (Atari 2600...
# 119  deepseek  hard  How did The Legend of Zelda: Ocarina of Time’s...
#
#                                                 answer  \
# 0    The Nintendo Entertainment System (NES) was re...
# 1    The game Pac-Man was developed by Toru Iwatani...
# 2    The game Sonic the Hedgehog was first released...
# 3    While there were many fighting games on the Su...
# 4    The Atari 2600 was developed and produced by A...
# ..                                                 ...
# 115  *Castlevania: Symphony of the Night* significa...
# 116  The Sega Dreamcast foreshadowed modern gaming ...
# 117  Both Tetris and Dr. Mario were released for th...
# 118  E.T. the Extra-Terrestrial for the Atari 2600 ...
# 119  The Legend of Zelda: Ocarina of Time's Z-targe...
#
#                                               entities  \
# 0       {'console': ['nintendo entertainment system']}
# 1                                {'game': ['pac-man']}
# 2    {'game': ['sonic the hedgehog'], 'console': [N...
# 3    {'game': [None], 'console': ['super nintendo e...
# 4    {'console': ['atari 2600'], 'publisher': ['ata...
# ..                                                 ...
# 115  {'game': ['castlevania: symphony of the night'...
# 116                    {'console': ['sega dreamcast']}
# 117  {'game': ['tetris', 'dr. mario'], 'console': [...
# 118        {'game': [None], 'console': ['atari 2600']}
# 119  {'game': ['the legend of zelda: ocarina of tim...
#
#                                             embeddings
# 0    [0.0004506858, 0.03856677, 0.06810948, 0.08225...
# 1    [0.012381856, 0.014237181, 0.027101945, 0.0473...
# 2    [-0.010663498, -0.007071837, 0.03953355, 0.039...
# 3    [-0.0005581793, 0.043345034, 0.05450761, 0.078...
# 4    [-0.022092162, 0.02777733, 0.06295724, 0.02797...
# ..                                                 ...
# 115  [-0.0040893066, 0.02658793, -0.0054087443, 0.0...
# 116  [-0.016330058, 0.025852317, 0.014798954, 0.023...
# 117  [0.004156725, 0.016723322, 0.027663492, 0.0203...
# 118  [0.034979213, -0.046446722, 0.0764473, 0.04750...
# 119  [0.0075873286, 0.037295394, 0.0034665635, 0.03...
#
# [120 rows x 6 columns]

# %%
df.to_parquet("../../data/qa_testset.parquet", index=False)
